# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook

# %%
county = pd.read_csv('county_facts.csv')
county
# Out:
#        fips           area_name state_abbreviation  PST045214  PST040210  \
# 0         0       United States                NaN  318857056  308758105
# 1      1000             Alabama                NaN    4849377    4780127
# 2      1001      Autauga County                 AL      55395      54571
# 3      1003      Baldwin County                 AL     200111     182265
# 4      1005      Barbour County                 AL      26887      27457
# 5      1007         Bibb County                 AL      22506      22919
# 6      1009       Blount County                 AL      57719      57322
# 7      1011      Bullock County                 AL      10764      10915
# 8      1013       Butler County                 AL      20296      20946
# 9      1015      Calhoun County                 AL     115916     118586
# 10     1017     Chambers County                 AL      34076      34170
# 11     1019     Cherokee County                 AL      26037      25986
# ...

# %%
primary = pd.read_csv('primary_results.csv')
primary
# Out:
#          state state_abbreviation                county        fips  \
# 0      Alabama                 AL               Autauga      1001.0
# 1      Alabama                 AL               Autauga      1001.0
# 2      Alabama                 AL               Baldwin      1003.0
# 3      Alabama                 AL               Baldwin      1003.0
# 4      Alabama                 AL               Barbour      1005.0
# 5      Alabama                 AL               Barbour      1005.0
# 6      Alabama                 AL                  Bibb      1007.0
# 7      Alabama                 AL                  Bibb      1007.0
# 8      Alabama                 AL                Blount      1009.0
# 9      Alabama                 AL                Blount      1009.0
# 10     Alabama                 AL               Bullock      1011.0
# 11     Alabama                 AL               Bullock      1011.0
# 12     Alabama                 AL                Butler      1013.0
# ...

# %%
primary['votes'].describe()
# Out:
# count     24611.000000
# mean       2306.252773
# std        9861.183572
# min           0.000000
# 25%          68.000000
# 50%         358.000000
# 75%        1375.000000
# max      590502.000000
# Name: votes, dtype: float64

# %%
state_votes = pd.DataFrame(primary.groupby('state')['votes'].sum())
state_votes
# Out:
#                   votes
# state
# Alabama         1223959
# Alaska            22469
# Arizona          834200
# Arkansas         605971
# California      4938197
# Colorado         121184
# Connecticut      531302
# Delaware         160416
# Florida         3940929
# Georgia         2032941
# Hawaii            46886
# Idaho            238989
# Illinois        3372537
# Indiana         1719291
# Iowa             326704
# Kansas           111296
# Kentucky         648885
# Louisiana        585781
# Maine              3415
# Maryland        1233272
# Massachusetts   1813320
# Michigan        2431111
# Mississippi      614200
# Missouri        1531672
# Montana          257516
# Nebraska         213691
# Nevada            86815
# New Hampshire    525966
# New Jersey      1321220
# New Mexico       309532
# New York        2686539
# North Carolina  2185747
# North Dakota        354
# Ohio            3204172
# Oklahoma         766123
# Oregon           933975
# Pennsylvania    3176340
# ...

# %%
# state_votes['votes'].len()

# %%
state_chart = state_votes.plot(kind='bar')

# %%
candidate_votes = pd.DataFrame(primary.groupby('candidate')['votes'].sum())
candidate_votes
# Out:
#                     votes
# candidate
#  No Preference       8152
#  Uncommitted           43
# Ben Carson         564553
# Bernie Sanders   11959102
# Carly Fiorina       15191
# Chris Christie      24353
# Donald Trump     13302541
# Hillary Clinton  15692452
# Jeb Bush            94411
# John Kasich       4159949
# Marco Rubio       3321076
# Martin O'Malley       752
# Mike Huckabee        3345
# Rand Paul            8479
# Rick Santorum        1782
# Ted Cruz          7603006

# %%
candidate_chart = candidate_votes.plot(kind='bar')
